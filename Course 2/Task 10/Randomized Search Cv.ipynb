# %% [markdown]
# # Grid SearchCV

# %%
# Library imports
import pandas as pd
import numpy as np
from datacleaner import autoclean
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score , make_scorer, mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %%
df=pd.read_csv(r"C:\Users\Maftuna\Desktop\Building_Permits.csv")
# Out:
# C:\Users\Maftuna\AppData\Local\Temp\ipykernel_15208\1941457807.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\Maftuna\Desktop\Building_Permits.csv")

# %%
df.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Permit Number                           198900 non-null  object
#  1   Permit Type                             198900 non-null  int64
#  2   Permit Type Definition                  198900 non-null  object
#  3   Permit Creation Date                    198900 non-null  object
#  4   Block                                   198900 non-null  object
#  5   Lot                                     198900 non-null  object
#  6   Street Number                           198900 non-null  int64
#  7   Street Number Suffix                    2216 non-null    object
#  8   Street Name                             198900 non-null  object
#  9   Street Suffix                           196132 non-null  object
# ...

# %%
df=autoclean(df)
# Out:
# c:\Users\Maftuna\anaconda3\Lib\site-packages\datacleaner\datacleaner.py:77: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   input_dataframe[column].fillna(input_dataframe[column].median(), inplace=True)
# c:\Users\Maftuna\anaconda3\Lib\site-packages\datacleaner\datacleaner.py:77: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Permit Number                           198900 non-null  int32
#  1   Permit Type                             198900 non-null  int64
#  2   Permit Type Definition                  198900 non-null  int32
#  3   Permit Creation Date                    198900 non-null  int32
#  4   Block                                   198900 non-null  int32
#  5   Lot                                     198900 non-null  int32
#  6   Street Number                           198900 non-null  int64
#  7   Street Number Suffix                    198900 non-null  int32
#  8   Street Name                             198900 non-null  int32
#  9   Street Suffix                           198900 non-null  int32
# ...

# %%
df.head()
# Out:
#    Permit Number  Permit Type  Permit Type Definition  Permit Creation Date  \
# 0          64721            4                       6                   472
# 1          92971            4                       6                   411
# 2          96216            3                       0                   545
# 3         109183            8                       5                  1115
# 4         110493            6                       1                  1177
#
#    Block  Lot  Street Number  Street Number Suffix  Street Name  \
# 0    325  351            140                     1          531
# 1    304  135            440                     1          642
# 2    516  725           1647                     1         1190
# 3    148  206           1230                     1         1190
# 4    341    1            950                     1         1006
#
#    Street Suffix  ...  Existing Construction Type  \
# 0             16  ...                         3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Permit Number                           198900 non-null  int32
#  1   Permit Type                             198900 non-null  int64
#  2   Permit Type Definition                  198900 non-null  int32
#  3   Permit Creation Date                    198900 non-null  int32
#  4   Block                                   198900 non-null  int32
#  5   Lot                                     198900 non-null  int32
#  6   Street Number                           198900 non-null  int64
#  7   Street Number Suffix                    198900 non-null  int32
#  8   Street Name                             198900 non-null  int32
#  9   Street Suffix                           198900 non-null  int32
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
num_col=df.select_dtypes(include='number').columns

# %%
df[num_col]=scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#    Permit Number  Permit Type  Permit Type Definition  Permit Creation Date  \
# 0      -0.497076    -2.416776                1.023150             -0.505438
# 1       0.044108    -2.416776                1.023150             -0.672299
# 2       0.106272    -3.102907               -3.455678             -0.305752
# 3       0.354681     0.327749                0.276678              1.253444
# 4       0.379776    -1.044513               -2.709206              1.423041
#
#       Block       Lot  Street Number  Street Number Suffix  Street Name  \
# 0 -1.180932  0.253067      -0.864376             -0.043933    -0.372384
# 1 -1.196115 -0.908658      -0.600237             -0.043933    -0.161541
# 2 -1.042841  2.264573       0.462482             -0.043933     0.879378
# 3 -1.308902 -0.526794       0.095329             -0.043933     0.879378
# 4 -1.169365 -1.629357      -0.151201             -0.043933     0.529872
#
#    Street Suffix  ...  Existing Construction Type  \
# ...

# %%
df.columns
# Out:
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition',
#        'Permit Creation Date', 'Block', 'Lot', 'Street Number',
#        'Street Number Suffix', 'Street Name', 'Street Suffix', 'Unit',
#        'Unit Suffix', 'Description', 'Current Status', 'Current Status Date',
#        'Filed Date', 'Issued Date', 'Completed Date',
#        'First Construction Document Date', 'Structural Notification',
#        'Number of Existing Stories', 'Number of Proposed Stories',
#        'Voluntary Soft-Story Retrofit', 'Fire Only Permit',
#        'Permit Expiration Date', 'Estimated Cost', 'Revised Cost',
#        'Existing Use', 'Existing Units', 'Proposed Use', 'Proposed Units',
#        'Plansets', 'TIDF Compliance', 'Existing Construction Type',
#        'Existing Construction Type Description', 'Proposed Construction Type',
#        'Proposed Construction Type Description', 'Site Permit',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries', 'Zipcode',
# ...

# %%
x = df.drop(columns=['Current Status'])
y = df['Current Status']

# %%
y
# Out:
# 0        -0.157472
# 1         1.023274
# 2         2.991184
# 3        -0.944636
# 4         1.023274
#             ...
# 198895    1.023274
# 198896    1.023274
# 198897    1.023274
# 198898    1.023274
# 198899    1.023274
# Name: Current Status, Length: 198900, dtype: float64

# %%
x_train,x_temp,y_train,y_temp=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test,x_val,y_test,y_val=train_test_split(x_temp,y_temp,test_size=0.5,random_state=42)

# %%
x_train.shape
# Out:
# (159120, 42)

# %%
y_train.shape
# Out:
# (159120,)

# %%
x_test.shape
# Out:
# (19890, 42)

# %%
y_test.shape
# Out:
# (19890,)

# %%
x_val.shape
# Out:
# (19890, 42)

# %%
y_val.shape
# Out:
# (19890,)

# %%
model=DecisionTreeRegressor(random_state=42)

# %%
model
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
dt_model=model.fit(x_train,y_train)

# %%
dt_model
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred=dt_model.predict(x_test)

# %%
y_pred
# Out:
# array([-0.94463635,  0.23610962, -0.94463635, ...,  1.0232736 ,
#        -0.94463635, -0.94463635])

# %%
y_pred
# Out:
# array([-0.94463635,  0.23610962, -0.94463635, ...,  1.0232736 ,
#        -0.94463635, -0.94463635])

# %%
r2=r2_score(y_test,y_pred)

# %%
print(r2)
# Out:
# 0.8606077063357295

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 0.1391590954813463

# %% [markdown]
# # Hyperparametr tuning:GridsearchCV

# %%
model = DecisionTreeRegressor(random_state=42)


param_grid = {
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}

# %%
param_grid
# Out:
# {'max_depth': [None, 10, 20, 30, 40, 50],
#  'min_samples_split': [2, 5, 10],
#  'min_samples_leaf': [1, 2, 4],
#  'max_features': [None, 'sqrt', 'log2']}

# %%
# Create scorers for MSE and R²
mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
r2_scorer = make_scorer(r2_score)

# %%
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring={'MSE': mse_scorer, 'R²': r2_scorer},
    refit='R²',  
    cv=5,        
    n_jobs=-1    
)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30, 40, 50],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              refit='R²',
#              scoring={'MSE': make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#                       'R²': make_scorer(r2_score, response_method='predict')})

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30, 40, 50],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              refit='R²',
#              scoring={'MSE': make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#                       'R²': make_scorer(r2_score, response_method='predict')})

# %%
best_params = grid_search.best_params_
print(f'Best Hyperparameters: {best_params}')
# Out:
# Best Hyperparameters: {'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
results = pd.DataFrame(grid_search.cv_results_)
print(results[['params', 'mean_test_MSE', 'mean_test_R²']])
# Out:
#                                                 params  mean_test_MSE  \
# 0    {'max_depth': None, 'max_features': None, 'min...      -0.152275
# 1    {'max_depth': None, 'max_features': None, 'min...      -0.145279
# 2    {'max_depth': None, 'max_features': None, 'min...      -0.135207
# 3    {'max_depth': None, 'max_features': None, 'min...      -0.137220
# 4    {'max_depth': None, 'max_features': None, 'min...      -0.135784
# ..                                                 ...            ...
# 157  {'max_depth': 50, 'max_features': 'log2', 'min...      -0.235988
# 158  {'max_depth': 50, 'max_features': 'log2', 'min...      -0.236765
# 159  {'max_depth': 50, 'max_features': 'log2', 'min...      -0.231517
# 160  {'max_depth': 50, 'max_features': 'log2', 'min...      -0.231517
# 161  {'max_depth': 50, 'max_features': 'log2', 'min...      -0.224186
#
#      mean_test_R²
# 0        0.847845
# 1        0.854838
# 2        0.864908
# 3        0.862895
# 4        0.864328
# ...

# %%
y_val_pred = grid_search.predict(x_val)


val_mse = mean_squared_error(y_val, y_val_pred)
val_r2 = r2_score(y_val, y_val_pred)
print(f'Validation MSE: {val_mse}')
print(f'Validation R²: {val_r2}')
# Out:
# Validation MSE: 0.10500660729189955
# Validation R²: 0.894499383955268

# %% [markdown]
# ## Randomized Search CV

# %%
model = DecisionTreeRegressor(random_state=42)

param_distributions = {
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 4, 6, 8],
    'max_features': [None, 'sqrt', 'log2']
}


mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
r2_scorer = make_scorer(r2_score)

# %%
# Compile setup
random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distributions,
    n_iter=20,          
    scoring={'MSE': mse_scorer, 'R²': r2_scorer},
    refit='R²',         
    cv=5,               
    n_jobs=-1,         
)

# %%
random_search
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'max_depth': [None, 10, 20, 30, 40, 50],
#                                         'max_features': [None, 'sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               20]},
#                    refit='R²',
#                    scoring={'MSE': make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#                             'R²': make_scorer(r2_score, response_method='predict')})

# %%
random_search.fit(x_train, y_train)


best_params = random_search.best_params_
print(f'Best Hyperparameters: {best_params}')
# Out:
# Best Hyperparameters: {'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': None, 'max_depth': 10}

# %%
random_search
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'max_depth': [None, 10, 20, 30, 40, 50],
#                                         'max_features': [None, 'sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               20]},
#                    refit='R²',
#                    scoring={'MSE': make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#                             'R²': make_scorer(r2_score, response_method='predict')})

# %%
results = pd.DataFrame(random_search.cv_results_)
print(results[['params', 'mean_test_MSE', 'mean_test_R²']])

y_val_pred = random_search.predict(x_val)


val_mse = mean_squared_error(y_val, y_val_pred)
val_r2 = r2_score(y_val, y_val_pred)
print(f'Validation MSE: {val_mse}')
print(f'Validation R²: {val_r2}')
# Out:
#                                                params  mean_test_MSE  \
# 0   {'min_samples_split': 2, 'min_samples_leaf': 6...      -0.107670
# 1   {'min_samples_split': 10, 'min_samples_leaf': ...      -0.113388
# 2   {'min_samples_split': 5, 'min_samples_leaf': 6...      -0.116569
# 3   {'min_samples_split': 20, 'min_samples_leaf': ...      -0.157154
# 4   {'min_samples_split': 5, 'min_samples_leaf': 2...      -0.108440
# 5   {'min_samples_split': 15, 'min_samples_leaf': ...      -0.114815
# 6   {'min_samples_split': 5, 'min_samples_leaf': 2...      -0.166861
# 7   {'min_samples_split': 15, 'min_samples_leaf': ...      -0.112284
# 8   {'min_samples_split': 10, 'min_samples_leaf': ...      -0.159488
# 9   {'min_samples_split': 5, 'min_samples_leaf': 1...      -0.252015
# 10  {'min_samples_split': 5, 'min_samples_leaf': 4...      -0.119901
# 11  {'min_samples_split': 5, 'min_samples_leaf': 4...      -0.167439
# 12  {'min_samples_split': 2, 'min_samples_leaf': 6...      -0.220607
# ...

# %%
# GridSearchCV
# Validation MSE: 0.10500660729189955
# Validation R²: 0.894499383955268
# Best Hyperparameters: {'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}




# RandomizedSearchCV
# Validation MSE: 0.10418310756092308
# Validation R²: 0.8953267578812646
# Best Hyperparameters: {'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': None, 'max_depth': 10}
